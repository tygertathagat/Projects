# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/tyger/.jupyter/ProjectsRune/MachineLearningWithPython-main/jupyter/starter/files/weather.csv', parse_dates= True, index_col= 0)

# %%
data.head()
# Out:
#             MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# Date
# 2008-02-01     19.5     22.4      15.6          6.2       0.0         NaN
# 2008-02-02     19.5     25.6       6.0          3.4       2.7         NaN
# 2008-02-03     21.6     24.5       6.6          2.4       0.1         NaN
# 2008-02-04     20.2     22.8      18.8          2.2       0.0         NaN
# 2008-02-05     19.7     25.7      77.4          NaN       0.0         NaN
#
#             WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  \
# Date                                                           ...
# 2008-02-01            NaN          S        SSW          17.0  ...
# 2008-02-02            NaN          W          E           9.0  ...
# 2008-02-03            NaN        ESE        ESE          17.0  ...
# 2008-02-04            NaN        NNE          E          22.0  ...
# 2008-02-05            NaN        NNE          W          11.0  ...
#
# ...

# %%
data.tail()
# Out:
#             MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# Date
# 2017-06-21      8.6     19.6       0.0          2.0       7.8         SSE
# 2017-06-22      9.3     19.2       0.0          2.0       9.2           W
# 2017-06-23      9.4     17.7       0.0          2.4       2.7           W
# 2017-06-24     10.1     19.3       0.0          1.4       9.3           W
# 2017-06-25      7.6     19.3       0.0          3.4       9.4           W
#
#             WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  \
# Date                                                           ...
# 2017-06-21           37.0          W        SSE          22.0  ...
# 2017-06-22           30.0          W        ESE          20.0  ...
# 2017-06-23           24.0        WNW          N          15.0  ...
# 2017-06-24           43.0          W          W          17.0  ...
# 2017-06-25           35.0          W          W          13.0  ...
#
# ...

# %%
data.index
# Out:
# DatetimeIndex(['2008-02-01', '2008-02-02', '2008-02-03', '2008-02-04',
#                '2008-02-05', '2008-02-06', '2008-02-07', '2008-02-08',
#                '2008-02-09', '2008-02-10',
#                ...
#                '2017-06-16', '2017-06-17', '2017-06-18', '2017-06-19',
#                '2017-06-20', '2017-06-21', '2017-06-22', '2017-06-23',
#                '2017-06-24', '2017-06-25'],
#               dtype='datetime64[ns]', name='Date', length=3337, freq=None)

# %%
dataset = data [['Humidity3pm','Pressure3pm','RainTomorrow']]

# %%
dataset.head()
# Out:
#             Humidity3pm  Pressure3pm RainTomorrow
# Date
# 2008-02-01         84.0       1017.4          Yes
# 2008-02-02         73.0       1016.4          Yes
# 2008-02-03         86.0       1015.6          Yes
# 2008-02-04         90.0       1011.8          Yes
# 2008-02-05         74.0       1004.8          Yes

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots()
dataset[dataset['RainTomorrow'] == 'No'].plot.scatter(x='Humidity3pm', y='Pressure3pm', c='purple', alpha=0.25, ax=ax)
dataset[dataset['RainTomorrow'] == 'Yes'].plot.scatter(x='Humidity3pm', y='Pressure3pm', c='orange', alpha=0.25, ax=ax)
# Out:
# <AxesSubplot:xlabel='Humidity3pm', ylabel='Pressure3pm'>

# %%
import numpy as np

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.metrics import accuracy_score

# %%
dataset_clean = dataset.dropna()

# %%
len(dataset),len(dataset_clean)
# Out:
# (3337, 3309)

# %%
X = dataset_clean[['Humidity3pm', 'Pressure3pm']]
y= dataset_clean['RainTomorrow']

y
# Out:
# Date
# 2008-02-01    Yes
# 2008-02-02    Yes
# 2008-02-03    Yes
# 2008-02-04    Yes
# 2008-02-05    Yes
#              ...
# 2017-06-21     No
# 2017-06-22     No
# 2017-06-23     No
# 2017-06-24     No
# 2017-06-25     No
# Name: RainTomorrow, Length: 3309, dtype: object

# %%
y = np.array([0 if value=='No' else 1 for value in y])
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state= 33)

# %%
neighbour = KNeighborsClassifier()
neighbour.fit(X_train,y_train)
y_prediction = neighbour.predict(X_test)
accuracy_score(y_test, y_prediction)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 0.7995169082125604

# %%
sum(y==1)/len(y)
# Out:
# 0.25929283771532186

# %%
X_map = np.random.rand(10000, 2)
X_map = X_map * (100, 50)+ (0, 990)
X_map
# Out:
# array([[  92.79871719, 1009.08298387],
#        [  60.81550776, 1030.85332431],
#        [  86.42611874, 1033.98388503],
#        ...,
#        [  10.25797986, 1038.16575769],
#        [  15.45082306, 1027.68402054],
#        [  93.91189248, 1011.43044796]])

# %%
fig, ax =plt.subplots()
Y_map = neighbour.predict(X_map)
ax.scatter(x=X_map[:,0], y=X_map[:,1], c=Y_map,alpha=0.90)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
scores = []
for k in range(1,100):
    neighbour = KNeighborsClassifier(n_neighbors=k)
    neighbour.fit(X_train,y_train)
    y_prediction = neighbour.predict(X_test)
    score = accuracy_score(y_test, y_prediction)
    scores.append(score)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
fig, ax = plt.subplots()
ax.plot(scores)
